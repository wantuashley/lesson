# %%
print("------智能设计骨架------")
print("识别手势")
print("色彩推荐")
print("自动排版")
print("风格推荐")
print("主体与背景分离")
print("文字识别")
print("风格滤镜迁移")
print("自动裁剪、适应尺寸")
print("参数化")
# Out:
# ------智能设计骨架------
# 识别手势
# 色彩推荐
# 自动排版
# 风格推荐
# 主体与背景分离
# 文字识别
# 风格滤镜迁移
# 自动裁剪、适应尺寸
# 参数化
