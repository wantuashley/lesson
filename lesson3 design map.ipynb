# %%
第三周作业
-----应用场景-----
检测海报中的主色彩群和海报品牌，探索品牌和色彩群关联性，形成品牌的“色彩图谱”。 比如对于设计师来说，如果要为食物产品做设计，就可以搜索哪些色彩是食物类品牌经常使用的，方便提供更多创意。

-----框架图-----
大量品牌关键词
↓
爬取海报
↓
色彩、品牌识别
↓
建立品牌&色彩图谱
↓
图谱可视化

-----实现思路-----
1.通过品牌关键字爬取一定数量的海报资源
2.使用imageai识别海报图像里的品牌和色彩
3.将品牌作为图中的节点，色彩在同一张品牌海报中出现则新增一条边，以此构建图谱
