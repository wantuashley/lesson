# %%
#step-01 用户输入一个图片，提取主色
def extract_main_color_from_image(image="图片")
    print(“图片主色调--”)

#step-02 图片主色rgb转hsv
def hsv_to_rgb(hsv=[]):
    hsv[0]/=2
    img_hsv=np.array([[hsv]],np.uint8)
    img_rgb = cv2.cvtColor(img_hsv, cv2.COLOR_HSV2RGB)
    plt.imshow(img_rgb)
    plt.show()
    return img_rgb

#step-03根据主色调hsv，从h=0开始，每36°取一组颜色，作为配色方案
for i in range(0,360,36):
    #print(i)
    a=hsv_to_rgb([i,255,255])
    b=hsv_to_rgb([i+36,255,255])
    print("推荐配色为——")
    print(a,b)
